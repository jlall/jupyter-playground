# %%
matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np
# Out:
#   File "<ipython-input-1-6bea0a0adb10>", line 1
#     matplotlib inline
#                     ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(0)
plots = []
for i in range(3):
    for j in range(3):
        ax = plt.subplot2grid((5,4), (i,j))
        #ax.scatter(range(20),range(20)+np.random.randint(-5,5,20))
plots
# Out:
# []

# %%
import pandas as pd
import numpy as np
import yfinance as yf
#from datetime import datetime, timedelta
import datetime

# %%
tk = yf.Ticker('AMZN')

# %%
ticker = yf.Ticker('VIXY')
df = ticker.history(period="3mo")
df['Close'].plot(title="stock price")
# Out:
# <AxesSubplot:title={'center':'stock price'}, xlabel='Date'>

# %%
    
    data = yf.download(  # or pdr.get_data_yahoo(...
            tickers = "VIXY",
            period = "1yr",
            interval = "1d",
            group_by = 'ticker',
            auto_adjust = True,
            prepost = True,
            threads = True,
            proxy = None
        )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data['^SPX']['Open'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Downloads/lobster/bird/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '^SPX'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-027d47160b55> in <module>
# ...

# %%
data['VIXY']['Close']
# Out:
# Date
# 2020-04-30    31.070000
# 2020-05-01    33.770000
# 2020-05-04    33.080002
# 2020-05-05    31.809999
# 2020-05-06    32.169998
#                 ...
# 2020-10-26    19.760000
# 2020-10-27    19.850000
# 2020-10-28    22.709999
# 2020-10-29    20.799999
# 2020-10-30    21.730000
# Name: Close, Length: 129, dtype: float64

# %%
data['^SPX']['Close']
# Out:
# Date
# 2020-04-30            NaN
# 2020-05-01            NaN
# 2020-05-04            NaN
# 2020-05-05            NaN
# 2020-05-06            NaN
#                  ...
# 2020-10-26            NaN
# 2020-10-27            NaN
# 2020-10-28            NaN
# 2020-10-29            NaN
# 2020-10-30    3269.959961
# Name: Close, Length: 129, dtype: float64

# %%
data['^VIX']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data['SPXL']['Open']
# Out:
# Date
# 2020-04-30    36.191186
# 2020-05-01    33.823725
# 2020-05-04    32.165506
# 2020-05-05    34.273245
# 2020-05-06    34.772708
#                 ...
# 2020-10-26    55.759998
# 2020-10-27    54.549999
# 2020-10-28    50.900002
# 2020-10-29    48.400002
# 2020-10-30    48.939999
# Name: Open, Length: 129, dtype: float64

# %%
data
# Out:
#                    ^SPX                                                       \
#                    Open         High          Low        Close        Volume
# Date
# 2020-04-30          NaN          NaN          NaN          NaN           NaN
# 2020-05-01          NaN          NaN          NaN          NaN           NaN
# 2020-05-04          NaN          NaN          NaN          NaN           NaN
# 2020-05-05          NaN          NaN          NaN          NaN           NaN
# 2020-05-06          NaN          NaN          NaN          NaN           NaN
# ...                 ...          ...          ...          ...           ...
# 2020-10-26          NaN          NaN          NaN          NaN           NaN
# 2020-10-27          NaN          NaN          NaN          NaN           NaN
# 2020-10-28          NaN          NaN          NaN          NaN           NaN
# 2020-10-29          NaN          NaN          NaN          NaN           NaN
# ...

# %%
data['VIXY']['Close'].plot()
data['SPXL']['Close'].plot()
data['^VIX']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import requests

# %%
requests.get('https://api.covidtracking.com/v1/us/daily.json')
# Out:
# <Response [200]>

# %%
l = requests.get('https://api.covidtracking.com/v1/us/daily.json')

# %%
l.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
l.json()
# Out:
# [{'date': 20201030,
#   'states': 56,
#   'positive': 8987631,
#   'negative': 119061648,
#   'pending': 11120,
#   'hospitalizedCurrently': 46688,
#   'hospitalizedCumulative': 473000,
#   'inIcuCurrently': 9437,
#   'inIcuCumulative': 24230,
#   'onVentilatorCurrently': 2477,
#   'onVentilatorCumulative': 2776,
#   'recovered': 3578452,
#   'dateChecked': '2020-10-30T00:00:00Z',
#   'death': 221356,
#   'hospitalized': 473000,
#   'totalTestResults': 144794227,
#   'lastModified': '2020-10-30T00:00:00Z',
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 933,
#   'hospitalizedIncrease': 2421,
#   'negativeIncrease': 980084,
#   'positiveIncrease': 97080,
#   'totalTestResultsIncrease': 1362376,
#   'hash': '24ff12b2c27f353bac3cdb9689c720229dda06e4'},
#  {'date': 20201029,
#   'states': 56,
#   'positive': 8890551,
#   'negative': 118081564,
#   'pending': 10481,
#   'hospitalizedCurrently': 46095,
#   'hospitalizedCumulative': 470579,
#   'inIcuCurrently': 9208,
# ...

# %%
df.read_json(l.json)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-0d2621b65d6d> in <module>
# ----> 1 df.read_json(l.json)
#
# NameError: name 'df' is not defined

# %%
a = pd.json_normalize(l.json())

# %%
a.['Date']
# Out:
#   File "<ipython-input-82-e99b5ea1524b>", line 1
#     a.['Date']
#       ^
# SyntaxError: invalid syntax

# %%
a
# Out:
#          date  states  positive   negative  pending  hospitalizedCurrently  \
# 0    20201030      56   8987631  119061648  11120.0                46688.0
# 1    20201029      56   8890551  118081564  10481.0                46095.0
# 2    20201028      56   8802099  117073522   9600.0                45045.0
# 3    20201027      56   8723438  116276445   8129.0                44212.0
# 4    20201026      56   8650342  115457526  11083.0                42917.0
# ..        ...     ...       ...        ...      ...                    ...
# 278  20200126       2         0          0      NaN                    NaN
# 279  20200125       2         0          0      NaN                    NaN
# 280  20200124       2         0          0      NaN                    NaN
# 281  20200123       2         0          0      NaN                    NaN
# 282  20200122       2         0          0      NaN                    NaN
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
b=a[['date','positiveIncrease']]
b.dtypes
# Out:
# date                int64
# positiveIncrease    int64
# dtype: object

# %%
b['date'].astype(str)
# Out:
# 0      20201030
# 1      20201029
# 2      20201028
# 3      20201027
# 4      20201026
#          ...
# 278    20200126
# 279    20200125
# 280    20200124
# 281    20200123
# 282    20200122
# Name: date, Length: 283, dtype: object

# %%
b.append(pd.to_datetime(b['date'], format='%Y%m%d'))
# Out:
#            date positiveIncrease      dates          0          1          2  \
# 0    2020-10-30            97080 2020-10-30        NaT        NaT        NaT
# 1    2020-10-29            88452 2020-10-29        NaT        NaT        NaT
# 2    2020-10-28            78661 2020-10-28        NaT        NaT        NaT
# 3    2020-10-27            73096 2020-10-27        NaT        NaT        NaT
# 4    2020-10-26            62274 2020-10-26        NaT        NaT        NaT
# ...         ...              ...        ...        ...        ...        ...
# 279  2020-01-25                0 2020-01-25        NaT        NaT        NaT
# 280  2020-01-24                0 2020-01-24        NaT        NaT        NaT
# 281  2020-01-23                0 2020-01-23        NaT        NaT        NaT
# 282  2020-01-22                0 2020-01-22        NaT        NaT        NaT
# date        NaT              NaT        NaT 2020-10-30 2020-10-29 2020-10-28
#
# ...

# %%
k = pd.to_datetime(b['date'], format='%Y%m%d')

# %%
b.append([k])
# Out:
#             date  positiveIncrease          0          1          2  \
# 0     20201030.0           97080.0        NaT        NaT        NaT
# 1     20201029.0           88452.0        NaT        NaT        NaT
# 2     20201028.0           78661.0        NaT        NaT        NaT
# 3     20201027.0           73096.0        NaT        NaT        NaT
# 4     20201026.0           62274.0        NaT        NaT        NaT
# ...          ...               ...        ...        ...        ...
# 279   20200125.0               0.0        NaT        NaT        NaT
# 280   20200124.0               0.0        NaT        NaT        NaT
# 281   20200123.0               0.0        NaT        NaT        NaT
# 282   20200122.0               0.0        NaT        NaT        NaT
# date         NaN               NaN 2020-10-30 2020-10-29 2020-10-28
#
#               3          4          5          6          7  ...        273  \
# ...

# %%
b
# Out:
#          date  positiveIncrease
# 0    20201030             97080
# 1    20201029             88452
# 2    20201028             78661
# 3    20201027             73096
# 4    20201026             62274
# ..        ...               ...
# 278  20200126                 0
# 279  20200125                 0
# 280  20200124                 0
# 281  20200123                 0
# 282  20200122                 0
#
# [283 rows x 2 columns]

# %%
b=a[['date','positiveIncrease']]
b.dtypes
# Out:
# date                int64
# positiveIncrease    int64
# dtype: object

# %%
b
# Out:
#          date  positiveIncrease
# 0    20201030             97080
# 1    20201029             88452
# 2    20201028             78661
# 3    20201027             73096
# 4    20201026             62274
# ..        ...               ...
# 278  20200126                 0
# 279  20200125                 0
# 280  20200124                 0
# 281  20200123                 0
# 282  20200122                 0
#
# [283 rows x 2 columns]

# %%
k
# Out:
# 0     2020-10-30
# 1     2020-10-29
# 2     2020-10-28
# 3     2020-10-27
# 4     2020-10-26
#          ...
# 278   2020-01-26
# 279   2020-01-25
# 280   2020-01-24
# 281   2020-01-23
# 282   2020-01-22
# Name: date, Length: 283, dtype: datetime64[ns]

# %%
b['dates'] = k
# Out:
# /home/ubuntu/Downloads/lobster/bird/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
k
# Out:
# 0     2020-10-30
# 1     2020-10-29
# 2     2020-10-28
# 3     2020-10-27
# 4     2020-10-26
#          ...
# 278   2020-01-26
# 279   2020-01-25
# 280   2020-01-24
# 281   2020-01-23
# 282   2020-01-22
# Name: date, Length: 283, dtype: datetime64[ns]

# %%
b['other'] = k
# Out:
# /home/ubuntu/Downloads/lobster/bird/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
b.insert(2,'dates',k,True)

# %%
b=(b[['positiveIncrease','dates']])

# %%
b
# Out:
#      positiveIncrease      dates
# 0               97080 2020-10-30
# 1               88452 2020-10-29
# 2               78661 2020-10-28
# 3               73096 2020-10-27
# 4               62274 2020-10-26
# ..                ...        ...
# 278                 0 2020-01-26
# 279                 0 2020-01-25
# 280                 0 2020-01-24
# 281                 0 2020-01-23
# 282                 0 2020-01-22
#
# [283 rows x 2 columns]

# %%
b.set_index('dates')
# Out:
#             positiveIncrease
# dates
# 2020-10-30             97080
# 2020-10-29             88452
# 2020-10-28             78661
# 2020-10-27             73096
# 2020-10-26             62274
# ...                      ...
# 2020-01-26                 0
# 2020-01-25                 0
# 2020-01-24                 0
# 2020-01-23                 0
# 2020-01-22                 0
#
# [283 rows x 1 columns]

# %%
b
# Out:
#      positiveIncrease      dates
# 0               97080 2020-10-30
# 1               88452 2020-10-29
# 2               78661 2020-10-28
# 3               73096 2020-10-27
# 4               62274 2020-10-26
# ..                ...        ...
# 278                 0 2020-01-26
# 279                 0 2020-01-25
# 280                 0 2020-01-24
# 281                 0 2020-01-23
# 282                 0 2020-01-22
#
# [283 rows x 2 columns]

# %%
j = b.set_index('dates')

# %%
j
# Out:
#             positiveIncrease
# dates
# 2020-10-30             97080
# 2020-10-29             88452
# 2020-10-28             78661
# 2020-10-27             73096
# 2020-10-26             62274
# ...                      ...
# 2020-01-26                 0
# 2020-01-25                 0
# 2020-01-24                 0
# 2020-01-23                 0
# 2020-01-22                 0
#
# [283 rows x 1 columns]

# %%
j.plot()
# Out:
# <AxesSubplot:xlabel='dates'>

# %%
data['VIXY']['Close'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Downloads/lobster/bird/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'VIXY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-175-2a16d06f2597> in <module>
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np
import pandas as pd
import numpy as np
import yfinance as yf
#from datetime import datetime, timedelta
import datetime
data = yf.download(  # or pdr.get_data_yahoo(...
        tickers = "VIXY SPXL",
        period = "1yr",
        interval = "1d",
        group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )

data['VIXY']['Close'].plot()
data['SPXL']['Close'].plot()
import requests
l = requests.get('https://api.covidtracking.com/v1/us/daily.json')
a = pd.json_normalize(l.json())
b=a[['date','positiveIncrease']]
k = pd.to_datetime(b['date'], format='%Y%m%d')
b = b.insert(2,'dates',k,True)
j = b.set_index('dates')
j.plot()
# Out:
# [*********************100%***********************]  2 of 2 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e40829aab55c> in <module>
#      26 k = pd.to_datetime(b['date'], format='%Y%m%d')
#      27 b= b.insert(2,'dates',k,True)
# ---> 28 j = b.set_index('dates')
#      29 j.plot()
#      30
#
# AttributeError: 'NoneType' object has no attribute 'set_index'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# dataframe sample data
df1 = pd.DataFrame(np.random.rand(10,2)*100, columns=['A', 'B'])
df2 = pd.DataFrame(np.random.rand(10,2)*100, columns=['A', 'B'])
df3 = pd.DataFrame(np.random.rand(10,2)*100, columns=['A', 'B'])
df4 = pd.DataFrame(np.random.rand(10,2)*100, columns=['A', 'B'])
df5 = pd.DataFrame(np.random.rand(10,2)*100, columns=['A', 'B'])
df6 = pd.DataFrame(np.random.rand(10,2)*100, columns=['A', 'B'])
#define number of rows and columns for subplots
nrow=3
ncol=2
# make a list of all dataframes 
df_list = [df1 ,df2, df3, df4, df5, df6]
fig, axes = plt.subplots(nrow, ncol)
# plot counter
count=0
for r in range(nrow):
    for c in range(ncol):
        df_list[count].plot(ax=axes[r,c])
        count=+1
